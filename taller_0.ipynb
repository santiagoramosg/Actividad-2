# %% [markdown]
# <a href="https://colab.research.google.com/github/santiagoramosg/Actividad-2/blob/main/taller_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#HOla

# %% [markdown]
# #casa

# %%
#crear lista
lista = [1,2,3,4,5]
import math
math.sqrt(25)
print(*lista, sep="\n")
# Out:
# 1
# 2
# 3
# 4
# 5
